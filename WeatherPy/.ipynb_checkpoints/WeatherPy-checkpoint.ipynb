# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import date

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
 # List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print("Beginning Data Retrieval")
print("----------------------------")
city_name=[]
city_longitude=[]
city_latitude=[]
city_max_temp=[]
city_humidity=[]
city_cloudiness=[]
city_wind_speed=[]
city_country=[]
city_date=[]

for index, city in enumerate(cities):
    try:
        response = requests.get(query_url + city).json()
        print(f"Processing Record {index+1} of set | {response['name']}")
        city_name.append(response["name"])
        city_longitude.append(response["coord"]["lon"])
        city_latitude.append(response["coord"]["lat"])
        city_max_temp.append(response["main"]["temp_max"])
        city_humidity.append(response["main"]["humidity"])
        city_cloudiness.append(response["clouds"]["all"])
        city_wind_speed.append(response["wind"]["speed"])
        city_country.append(response["sys"]["country"])
        city_date.append(response["dt"])
    except KeyError:
        print("City not found. Skipping...")
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# City not found. Skipping...
# Processing Record 2 of set | Batagay-Alyta
# Processing Record 3 of set | Albany
# Processing Record 4 of set | Nha Trang
# Processing Record 5 of set | Rikitea
# Processing Record 6 of set | Jais
# City not found. Skipping...
# Processing Record 8 of set | Aykhal
# Processing Record 9 of set | Barrow
# Processing Record 10 of set | Chokurdakh
# Processing Record 11 of set | Comodoro Rivadavia
# Processing Record 12 of set | São João da Barra
# Processing Record 13 of set | Qasigiannguit
# City not found. Skipping...
# Processing Record 15 of set | Atuona
# Processing Record 16 of set | Upernavik
# Processing Record 17 of set | Saint-Augustin
# Processing Record 18 of set | Leningradskiy
# Processing Record 19 of set | New Iberia
# Processing Record 20 of set | Hermanus
# Processing Record 21 of set | Matara
# City not found. Skipping...
# Processing Record 23 of set | Shimoda
# Processing Record 24 of set | Bluff
# Processing Record 25 of set | Coari
# Processing Record 26 of set | Qaanaaq
# Processing Record 27 of set | Busselton
# Processing Record 28 of set | Punta Arenas
# Processing Record 29 of set | Vestmannaeyjar
# Processing Record 30 of set | Grindavik
# Processing Record 31 of set | Arrifes
# Processing Record 32 of set | Tiksi
# Processing Record 33 of set | Hithadhoo
# Processing Record 34 of set | Hobart
# City not found. Skipping...
# Processing Record 36 of set | Mataura
# Processing Record 37 of set | Lüderitz
# Processing Record 38 of set | Mirpur Sakro
# Processing Record 39 of set | Provideniya
# Processing Record 40 of set | Port Alfred
# Processing Record 41 of set | Kapaa
# Processing Record 42 of set | Bredasdorp
# Processing Record 43 of set | Saint-Philippe
# Processing Record 44 of set | Catia La Mar
# Processing Record 45 of set | Hong Kong
# Processing Record 46 of set | Bandarbeyla
# Processing Record 47 of set | Terney
# Processing Record 48 of set | Antofagasta
# Processing Record 49 of set | Severo-Kuril'sk
# Processing Record 50 of set | Nikolskoye
# Processing Record 51 of set | Taveta
# Processing Record 52 of set | Carnduff
# City not found. Skipping...
# Processing Record 54 of set | Bud
# Processing Record 55 of set | Todos Santos
# Processing Record 56 of set | Nampula
# Processing Record 57 of set | Longyearbyen
# Processing Record 58 of set | Ushuaia
# Processing Record 59 of set | Cidreira
# Processing Record 60 of set | Ogulin
# City not found. Skipping...
# Processing Record 62 of set | Nyurba
# Processing Record 63 of set | Codrington
# Processing Record 64 of set | Acapulco de Juárez
# Processing Record 65 of set | Corinth
# City not found. Skipping...
# Processing Record 67 of set | Shitanjing
# Processing Record 68 of set | Progreso
# Processing Record 69 of set | Seoul
# City not found. Skipping...
# Processing Record 71 of set | San Jose de Guanipa
# Processing Record 72 of set | Tasiilaq
# Processing Record 73 of set | Torbay
# Processing Record 74 of set | Puerto Ayora
# Processing Record 75 of set | Sabang
# Processing Record 76 of set | Smithers
# Processing Record 77 of set | Cherskiy
# Processing Record 78 of set | Souillac
# Processing Record 79 of set | Cape Town
# Processing Record 80 of set | Novyy Svit
# City not found. Skipping...
# Processing Record 82 of set | Tura
# Processing Record 83 of set | Ayan
# Processing Record 84 of set | Harper
# Processing Record 85 of set | Sioux Lookout
# Processing Record 86 of set | Port Elizabeth
# City not found. Skipping...
# Processing Record 88 of set | Shimanovsk
# Processing Record 89 of set | Magadan
# City not found. Skipping...
# Processing Record 91 of set | São Filipe
# Processing Record 92 of set | Isangel
# Processing Record 93 of set | Talnakh
# Processing Record 94 of set | Kruisfontein
# Processing Record 95 of set | Kamenka
# Processing Record 96 of set | Ust-Kuyga
# Processing Record 97 of set | Dicabisagan
# Processing Record 98 of set | Castro
# Processing Record 99 of set | Avarua
# Processing Record 100 of set | Gizo Government Station
# Processing Record 101 of set | Sitka
# Processing Record 102 of set | Wonthaggi
# Processing Record 103 of set | Saint Paul Harbor
# Processing Record 104 of set | Erenhot
# Processing Record 105 of set | Guayaramerín
# Processing Record 106 of set | Hilo
# Processing Record 107 of set | Salalah
# City not found. Skipping...
# Processing Record 109 of set | Nizwá
# Processing Record 110 of set | Khatanga
# City not found. Skipping...
# Processing Record 112 of set | Coquimbo
# Processing Record 113 of set | Touros
# Processing Record 114 of set | Whangarei
# Processing Record 115 of set | Preiļi
# Processing Record 116 of set | Ribeira Grande
# Processing Record 117 of set | Jamestown
# Processing Record 118 of set | Mahébourg
# Processing Record 119 of set | Sayán
# Processing Record 120 of set | Vaini
# Processing Record 121 of set | Zlobin
# Processing Record 122 of set | Kodinsk
# Processing Record 123 of set | Chadiza
# Processing Record 124 of set | Yellowknife
# Processing Record 125 of set | Quatre Cocos
# Processing Record 126 of set | Kirovskiy
# Processing Record 127 of set | Radford
# Processing Record 128 of set | Necochea
# Processing Record 129 of set | Kerrville
# City not found. Skipping...
# Processing Record 131 of set | Thompson
# Processing Record 132 of set | Madang
# Processing Record 133 of set | Walvis Bay
# Processing Record 134 of set | Vila Franca do Campo
# Processing Record 135 of set | San Matías
# Processing Record 136 of set | Ponta do Sol
# Processing Record 137 of set | Saint George
# Processing Record 138 of set | Manavgat
# Processing Record 139 of set | Sur
# Processing Record 140 of set | Dikson
# Processing Record 141 of set | Biltine
# Processing Record 142 of set | Khabary
# Processing Record 143 of set | Igbaras
# Processing Record 144 of set | George Town
# Processing Record 145 of set | Kavaratti
# Processing Record 146 of set | Orán
# Processing Record 147 of set | Mossamedes
# Processing Record 148 of set | Nelson Bay
# Processing Record 149 of set | Toora-Khem
# Processing Record 150 of set | Puerto Escondido
# Processing Record 151 of set | Husavik
# Processing Record 152 of set | Boromo
# Processing Record 153 of set | Ekhabi
# City not found. Skipping...
# Processing Record 155 of set | Okhotsk
# Processing Record 156 of set | Pathanāmthitta
# Processing Record 157 of set | Srednekolymsk
# Processing Record 158 of set | Dabakala
# Processing Record 159 of set | Gisborne
# Processing Record 160 of set | Tortolì
# Processing Record 161 of set | Arraial do Cabo
# Processing Record 162 of set | Oranjemund
# Processing Record 163 of set | Butaritari
# Processing Record 164 of set | Burriana
# Processing Record 165 of set | Berlevåg
# Processing Record 166 of set | Olafsvik
# City not found. Skipping...
# Processing Record 168 of set | Cap Malheureux
# Processing Record 169 of set | Mikhaylov
# Processing Record 170 of set | College
# Processing Record 171 of set | Makat
# Processing Record 172 of set | Katherine
# Processing Record 173 of set | Saskylakh
# Processing Record 174 of set | Laguna
# Processing Record 175 of set | Bella Union
# Processing Record 176 of set | Shenjiamen
# Processing Record 177 of set | Kongolo
# Processing Record 178 of set | Aden
# Processing Record 179 of set | Bariloche
# Processing Record 180 of set | Coxim
# City not found. Skipping...
# Processing Record 182 of set | Aswān
# Processing Record 183 of set | Arlit
# Processing Record 184 of set | Cabo San Lucas
# Processing Record 185 of set | Morant Bay
# Processing Record 186 of set | Maturin
# Processing Record 187 of set | Isla Aguada
# Processing Record 188 of set | Tomatlán
# Processing Record 189 of set | Tucumã
# Processing Record 190 of set | Aasiaat
# Processing Record 191 of set | Udachny
# Processing Record 192 of set | Majene
# Processing Record 193 of set | Muravlenko
# Processing Record 194 of set | Itarema
# Processing Record 195 of set | Betanzos
# Processing Record 196 of set | Mizdah
# Processing Record 197 of set | San Patricio
# Processing Record 198 of set | Henderson
# City not found. Skipping...
# Processing Record 200 of set | Lebu
# Processing Record 201 of set | Lorengau
# Processing Record 202 of set | Lagoa
# Processing Record 203 of set | Krosno
# City not found. Skipping...
# Processing Record 205 of set | Sibu
# Processing Record 206 of set | Vysokogornyy
# City not found. Skipping...
# Processing Record 208 of set | North Platte
# Processing Record 209 of set | Carutapera
# Processing Record 210 of set | Anadyr
# Processing Record 211 of set | Eyl
# Processing Record 212 of set | Camacha
# Processing Record 213 of set | Lokosovo
# Processing Record 214 of set | Poum
# Processing Record 215 of set | Faanui
# Processing Record 216 of set | Xichang
# Processing Record 217 of set | Norman Wells
# Processing Record 218 of set | Road Town
# Processing Record 219 of set | Kuytun
# Processing Record 220 of set | Geraldton
# City not found. Skipping...
# Processing Record 222 of set | Takoradze
# Processing Record 223 of set | Mishan
# Processing Record 224 of set | Sergeevka
# Processing Record 225 of set | Haines Junction
# Processing Record 226 of set | La Rioja
# City not found. Skipping...
# Processing Record 228 of set | Orlik
# Processing Record 229 of set | Korla
# Processing Record 230 of set | Tapejara
# Processing Record 231 of set | Mirny
# Processing Record 232 of set | Charter Township of Clinton
# Processing Record 233 of set | Matthews
# Processing Record 234 of set | Kisangani
# Processing Record 235 of set | Egvekinot
# Processing Record 236 of set | Agüimes
# Processing Record 237 of set | Człuchów
# Processing Record 238 of set | Bambous Virieux
# Processing Record 239 of set | Nemuro
# Processing Record 240 of set | Deneysville
# Processing Record 241 of set | Svetlaya
# Processing Record 242 of set | Sumpango
# Processing Record 243 of set | Ko Samui
# Processing Record 244 of set | Hazaribagh
# Processing Record 245 of set | Grand Gaube
# Processing Record 246 of set | Bethel
# Processing Record 247 of set | Alofi
# Processing Record 248 of set | Nanortalik
# Processing Record 249 of set | Khorixas
# Processing Record 250 of set | Rapid Valley
# Processing Record 251 of set | Awjilah
# Processing Record 252 of set | Carnarvon
# Processing Record 253 of set | Bengkulu
# Processing Record 254 of set | Ternate
# Processing Record 255 of set | Santa Maria
# Processing Record 256 of set | Bucerías
# Processing Record 257 of set | Mazamari
# Processing Record 258 of set | Gwadar
# Processing Record 259 of set | Shingū
# Processing Record 260 of set | Yichun
# Processing Record 261 of set | Qaqortoq
# Processing Record 262 of set | Olinda
# Processing Record 263 of set | Tuktoyaktuk
# City not found. Skipping...
# Processing Record 265 of set | Vangaindrano
# Processing Record 266 of set | Yar-Sale
# Processing Record 267 of set | Ericeira
# Processing Record 268 of set | Tigre
# Processing Record 269 of set | Lata
# Processing Record 270 of set | Mocuba
# Processing Record 271 of set | Bitam
# Processing Record 272 of set | Hasaki
# Processing Record 273 of set | Champerico
# Processing Record 274 of set | Puerto Suárez
# Processing Record 275 of set | Port-Cartier
# Processing Record 276 of set | Waipawa
# Processing Record 277 of set | Ostrovnoy
# Processing Record 278 of set | San Pascual
# Processing Record 279 of set | Uşak Province
# City not found. Skipping...
# Processing Record 281 of set | Airai
# Processing Record 282 of set | Ponta Delgada
# Processing Record 283 of set | General Roca
# Processing Record 284 of set | Arrondissement de Mont-de-Marsan
# Processing Record 285 of set | Severo-Yeniseyskiy
# Processing Record 286 of set | Bestöbe
# Processing Record 287 of set | Pangody
# Processing Record 288 of set | Tuensang
# Processing Record 289 of set | Allāpalli
# Processing Record 290 of set | Murgab
# Processing Record 291 of set | Nantucket
# Processing Record 292 of set | Chuzhou
# Processing Record 293 of set | New Norfolk
# Processing Record 294 of set | Birao
# Processing Record 295 of set | La Providencia
# Processing Record 296 of set | Rutana Province
# Processing Record 297 of set | Urusha
# Processing Record 298 of set | Chui
# City not found. Skipping...
# Processing Record 300 of set | Livingston
# Processing Record 301 of set | Kaitangata
# Processing Record 302 of set | Iqaluit
# Processing Record 303 of set | Arkhangelsk
# Processing Record 304 of set | Mount Gambier
# Processing Record 305 of set | Ilulissat
# Processing Record 306 of set | Pineville
# Processing Record 307 of set | Alekseyevsk
# Processing Record 308 of set | Dingle
# Processing Record 309 of set | Evanston
# Processing Record 310 of set | Kavieng
# Processing Record 311 of set | Ukiah
# City not found. Skipping...
# Processing Record 313 of set | Faya
# Processing Record 314 of set | Portland
# City not found. Skipping...
# Processing Record 316 of set | Heihe
# Processing Record 317 of set | Richards Bay
# Processing Record 318 of set | Kungurtug
# Processing Record 319 of set | Klaksvík
# Processing Record 320 of set | Atar
# Processing Record 321 of set | Bowen
# Processing Record 322 of set | Sala Consilina
# Processing Record 323 of set | La Ronge
# Processing Record 324 of set | Pangnirtung
# Processing Record 325 of set | Kathu
# Processing Record 326 of set | Maniitsoq
# City not found. Skipping...
# Processing Record 328 of set | Nānākuli
# Processing Record 329 of set | Tuatapere
# Processing Record 330 of set | Marystown
# Processing Record 331 of set | Abay
# Processing Record 332 of set | Batangafo
# Processing Record 333 of set | Sweetwater
# Processing Record 334 of set | Vacaria
# Processing Record 335 of set | Basco
# Processing Record 336 of set | Saint Anthony
# Processing Record 337 of set | Mahon
# Processing Record 338 of set | Llanelli
# Processing Record 339 of set | Sakaiminato
# Processing Record 340 of set | East London
# Processing Record 341 of set | Zhangye
# Processing Record 342 of set | Hamilton
# Processing Record 343 of set | São Miguel do Araguaia
# Processing Record 344 of set | Santa Rosa
# Processing Record 345 of set | Tegul'det
# Processing Record 346 of set | Puri
# Processing Record 347 of set | Mitzic
# Processing Record 348 of set | Pochutla
# Processing Record 349 of set | Guerrero Negro
# Processing Record 350 of set | Cururupu
# Processing Record 351 of set | Simao
# Processing Record 352 of set | Pisco
# Processing Record 353 of set | Baymak
# Processing Record 354 of set | San Quintín
# Processing Record 355 of set | Clyde River
# Processing Record 356 of set | Almonte
# Processing Record 357 of set | Kenai
# Processing Record 358 of set | Luwuk
# Processing Record 359 of set | Ancud
# Processing Record 360 of set | Saint-Leu
# Processing Record 361 of set | Synya
# Processing Record 362 of set | Alyangula
# Processing Record 363 of set | Esil
# Processing Record 364 of set | Warrnambool
# Processing Record 365 of set | Ilhabela
# Processing Record 366 of set | Kitimat
# Processing Record 367 of set | Santa Cruz de la Sierra
# Processing Record 368 of set | Te Anau
# Processing Record 369 of set | Kendari
# City not found. Skipping...
# Processing Record 371 of set | Opuwo
# Processing Record 372 of set | Bharatpur
# Processing Record 373 of set | Loandjili
# Processing Record 374 of set | The Pas
# Processing Record 375 of set | Rome
# City not found. Skipping...
# Processing Record 377 of set | Tsimlyansk
# Processing Record 378 of set | Aksu
# Processing Record 379 of set | Taman'
# Processing Record 380 of set | Auki
# City not found. Skipping...
# Processing Record 382 of set | Kantunilkín
# Processing Record 383 of set | Safranbolu
# Processing Record 384 of set | Kinkala
# City not found. Skipping...
# Processing Record 386 of set | Narsaq
# Processing Record 387 of set | Taoudenni
# Processing Record 388 of set | Sibolga
# Processing Record 389 of set | Yei
# Processing Record 390 of set | Praia da Vitória
# Processing Record 391 of set | Kisi
# Processing Record 392 of set | Tambura
# Processing Record 393 of set | Artvin Province
# Processing Record 394 of set | Kandi
# Processing Record 395 of set | Zhangzhou
# Processing Record 396 of set | Frutigen
# Processing Record 397 of set | Balkanabat
# Processing Record 398 of set | Gilching
# Processing Record 399 of set | Keetmanshoop
# Processing Record 400 of set | Syracuse
# Processing Record 401 of set | Miandrivazo
# Processing Record 402 of set | Ngunguru
# Processing Record 403 of set | Adrar
# City not found. Skipping...
# Processing Record 405 of set | Bockenem
# Processing Record 406 of set | Three Hills
# Processing Record 407 of set | Namatanai
# City not found. Skipping...
# Processing Record 409 of set | Manzanillo
# Processing Record 410 of set | Gwalior
# Processing Record 411 of set | Naze
# Processing Record 412 of set | Ahome
# Processing Record 413 of set | Ves'yegonsk
# Processing Record 414 of set | Neuquén
# Processing Record 415 of set | Barcelos
# Processing Record 416 of set | Port Shepstone
# Processing Record 417 of set | Kumul
# Processing Record 418 of set | Lososina
# Processing Record 419 of set | Nicolás R Casillas
# Processing Record 420 of set | Pemba
# Processing Record 421 of set | Padang
# City not found. Skipping...
# Processing Record 423 of set | Fort Nelson
# Processing Record 424 of set | Mar del Plata
# Processing Record 425 of set | Marsá Maţrūḩ
# Processing Record 426 of set | Darłowo
# Processing Record 427 of set | Umba
# Processing Record 428 of set | Maracaçumé
# Processing Record 429 of set | Flin Flon
# Processing Record 430 of set | Otradnoye
# Processing Record 431 of set | Clovis
# Processing Record 432 of set | Barreirinhas
# Processing Record 433 of set | Deputatsky
# Processing Record 434 of set | São João de Pirabas
# Processing Record 435 of set | Nouadhibou
# Processing Record 436 of set | Salinópolis
# Processing Record 437 of set | Kutum
# Processing Record 438 of set | Puerto Baquerizo Moreno
# Processing Record 439 of set | Mayumba
# Processing Record 440 of set | Yangi Marg`ilon
# Processing Record 441 of set | Avera
# Processing Record 442 of set | Arzgir
# City not found. Skipping...
# Processing Record 444 of set | Nuuk
# Processing Record 445 of set | Tigil'
# Processing Record 446 of set | Peruíbe
# Processing Record 447 of set | Nanga Eboko
# Processing Record 448 of set | Witu
# Processing Record 449 of set | Cockburn Town
# Processing Record 450 of set | Alice Springs
# Processing Record 451 of set | Porbandar
# Processing Record 452 of set | Iquique
# City not found. Skipping...
# Processing Record 454 of set | Kedrovyy
# Processing Record 455 of set | Rudnogorsk
# Processing Record 456 of set | Argentan
# Processing Record 457 of set | Vila Velha
# Processing Record 458 of set | Kieta
# City not found. Skipping...
# Processing Record 460 of set | São José da Coroa Grande
# Processing Record 461 of set | Fortuna
# Processing Record 462 of set | Ahipara
# Processing Record 463 of set | Qingyuan
# Processing Record 464 of set | São Félix do Xingu
# Processing Record 465 of set | Waingapu
# Processing Record 466 of set | Hohhot
# City not found. Skipping...
# Processing Record 468 of set | Rubiataba
# Processing Record 469 of set | Hwange
# Processing Record 470 of set | Tulum
# Processing Record 471 of set | Voiron
# Processing Record 472 of set | Mezen'
# City not found. Skipping...
# Processing Record 474 of set | Baker City
# Processing Record 475 of set | Tieli
# Processing Record 476 of set | Saint-Pierre
# Processing Record 477 of set | Ol'ga
# Processing Record 478 of set | Natal
# Processing Record 479 of set | Yemtsa
# Processing Record 480 of set | Emirdağ
# Processing Record 481 of set | Mayo
# Processing Record 482 of set | Zhezkazgan
# Processing Record 483 of set | Sharan
# Processing Record 484 of set | Wajid
# Processing Record 485 of set | Nome
# Processing Record 486 of set | San Luis
# Processing Record 487 of set | Lavrentiya
# Processing Record 488 of set | Shīeli
# Processing Record 489 of set | Siilinjärvi
# City not found. Skipping...
# Processing Record 491 of set | Coyhaique
# Processing Record 492 of set | Bonavista
# Processing Record 493 of set | Hofn
# Processing Record 494 of set | Pecos
# Processing Record 495 of set | Częstochowa
# Processing Record 496 of set | Kununurra
# Processing Record 497 of set | Los Alamos
# City not found. Skipping...
# Processing Record 499 of set | Taraz
# Processing Record 500 of set | Sørland
# Processing Record 501 of set | Dingli
# Processing Record 502 of set | Bereket
# Processing Record 503 of set | Denpasar
# Processing Record 504 of set | Honningsvåg
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 507 of set | Maningrida
# Processing Record 508 of set | Sobolevo
# Processing Record 509 of set | Yulara
# Processing Record 510 of set | Ulladulla
# Processing Record 511 of set | Mount Isa
# Processing Record 512 of set | Kloulklubed
# Processing Record 513 of set | Labuhan
# Processing Record 514 of set | Kysyl-Syr
# Processing Record 515 of set | Baharly
# Processing Record 516 of set | Andra
# Processing Record 517 of set | Bonthe
# Processing Record 518 of set | Eureka
# Processing Record 519 of set | Delta del Tigre
# Processing Record 520 of set | Silveira
# Processing Record 521 of set | Wagar
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 524 of set | Ugoofaaru
# Processing Record 525 of set | Deli Tua
# Processing Record 526 of set | Isiro
# Processing Record 527 of set | Taltal
# Processing Record 528 of set | Zhuhai
# Processing Record 529 of set | Carballo
# Processing Record 530 of set | Mandalī
# Processing Record 531 of set | Buin
# Processing Record 532 of set | Aranos
# Processing Record 533 of set | La Serena
# Processing Record 534 of set | Fuzhou
# Processing Record 535 of set | Nowy Dwór Gdański
# Processing Record 536 of set | Bāglung
# Processing Record 537 of set | Honiara
# Processing Record 538 of set | Petra
# Processing Record 539 of set | Zhigansk
# Processing Record 540 of set | Morón
# Processing Record 541 of set | Mitsamiouli
# Processing Record 542 of set | Pangai
# Processing Record 543 of set | Merrill
# Processing Record 544 of set | Mumford
# Processing Record 545 of set | Kupang
# Processing Record 546 of set | Kawalu
# Processing Record 547 of set | Sisimiut
# Processing Record 548 of set | Bang Saphan
# Processing Record 549 of set | Kytmanovo
# City not found. Skipping...
# Processing Record 551 of set | Limbang
# Processing Record 552 of set | Dunedin
# Processing Record 553 of set | Samarai
# Processing Record 554 of set | Mozelos
# Processing Record 555 of set | Pacific Grove
# Processing Record 556 of set | Ingham
# Processing Record 557 of set | Northam
# Processing Record 558 of set | Monster
# Processing Record 559 of set | Havøysund
# Processing Record 560 of set | Aloleng
# Processing Record 561 of set | Pevek
# Processing Record 562 of set | Bubaque
# Processing Record 563 of set | Lázaro Cárdenas
# Processing Record 564 of set | Westport
# Processing Record 565 of set | Baruun-Urt
# Processing Record 566 of set | Beloha
# Processing Record 567 of set | Fethiye
# Processing Record 568 of set | Senanga
# Processing Record 569 of set | Leshukonskoye
# Processing Record 570 of set | Talara
# Processing Record 571 of set | Caravelas
# Processing Record 572 of set | Fremont
# City not found. Skipping...
# Processing Record 574 of set | Manzhouli
# Processing Record 575 of set | Shubarkuduk
# Processing Record 576 of set | Ketchikan
# Processing Record 577 of set | Oddur
# Processing Record 578 of set | Nizhniy Tsasuchey
# Processing Record 579 of set | San Juan
# Processing Record 580 of set | Sargodha
# Processing Record 581 of set | Gebze
# Processing Record 582 of set | Ulaangom
# Processing Record 583 of set | Port Augusta
# Processing Record 584 of set | Fuling
# Processing Record 585 of set | Adeje
# Processing Record 586 of set | Karachi
# Processing Record 587 of set | Vao
# Processing Record 588 of set | Kohima
# Processing Record 589 of set | San Cristobal
# Processing Record 590 of set | Talaya
# Processing Record 591 of set | Big Rapids
# Processing Record 592 of set | Bilibino
# Processing Record 593 of set | Lagos
# Processing Record 594 of set | Kudahuvadhoo
# Processing Record 595 of set | Riberalta
# City not found. Skipping...
# Processing Record 597 of set | Kahului
# Processing Record 598 of set | Banepā
# Processing Record 599 of set | Inírida
# Processing Record 600 of set | Sangar
# Processing Record 601 of set | Bahía Blanca
# Processing Record 602 of set | Tinskoy
# Processing Record 603 of set | Burnie
# Processing Record 604 of set | Charyshskoye
# Processing Record 605 of set | Madimba
# Processing Record 606 of set | Constitución
# Processing Record 607 of set | Māyakonda
# Processing Record 608 of set | Benghazi
# Processing Record 609 of set | Buraidah
# Processing Record 610 of set | Severnoye
# Processing Record 611 of set | Mildura
# Processing Record 612 of set | Byron Bay
# Processing Record 613 of set | Zaraza
# Processing Record 614 of set | Mananara
# Processing Record 615 of set | Aberfoyle
# Processing Record 616 of set | Diffa
# Processing Record 617 of set | Ipixuna
# Processing Record 618 of set | Tarko-Sale
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df=pd.DataFrame({
    "City": city_name,
    "Cloudiness": city_cloudiness,
    "Country": city_country,
    "Date": city_date,
    "Humidity":city_humidity,
    "Lat":city_latitude,
    "Lng":city_longitude,
    "Max Temp":city_max_temp,  
    "Wind": city_wind_speed,    
})
weather_df["Lat"]=weather_df["Lat"].astype(float).round(2)
weather_df["Lng"]=weather_df["Lng"].astype(float).round(2)
weather_df["City"]=weather_df["City"].str.lower()


weather_df.to_csv("Cities.csv",index=False)

weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568 entries, 0 to 567
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        568 non-null    object
#  1   Cloudiness  568 non-null    int64
#  2   Country     568 non-null    object
#  3   Date        568 non-null    int64
#  4   Humidity    568 non-null    int64
#  5   Lat         568 non-null    float64
#  6   Lng         568 non-null    float64
#  7   Max Temp    568 non-null    float64
#  8   Wind        568 non-null    float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 40.1+ KB

# %%
weather_df.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  568.000000  5.680000e+02  568.000000  568.000000  568.000000
# mean    59.186620  1.634744e+09   69.531690   20.338838   19.675194
# std     38.415537  7.643423e+01   20.627948   33.710365   89.787920
# min      0.000000  1.634744e+09    1.000000  -54.800000 -179.170000
# 25%     20.000000  1.634744e+09   59.000000   -8.032500  -57.950000
# 50%     75.000000  1.634744e+09   72.000000   25.015000   24.965000
# 75%     97.000000  1.634745e+09   86.000000   48.812500   98.880000
# max    100.000000  1.634745e+09  100.000000   78.220000  178.420000
#
#          Max Temp        Wind
# count  568.000000  568.000000
# mean    61.493944    7.943592
# std     21.915196    5.767320
# min    -17.900000    0.000000
# 25%     44.152500    3.552500
# 50%     67.975000    6.820000
# 75%     78.667500   10.867500
# max    101.700000   41.340000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.loc[weather_df["Humidity"]>100]
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind]
# Index: []

# %%
weather_df.loc[weather_df["Humidity"]>100]
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind]
# Index: []

# %%
weather_df.loc[weather_df["Humidity"]>100].index
# Out:
# Int64Index([], dtype='int64')

# %%
weather_df["Humidity"].max()
# Out:
# 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_latitude, city_max_temp,edgecolor="black",alpha=0.75)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs. Max Temperature ({date.today().strftime('%m/%d/%Y')})")
plt.savefig("../Images/Latitude_vs_Temperature.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_latitude, city_humidity,edgecolor="black",alpha=0.75)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity ({date.today().strftime('%m/%d/%Y')})")
plt.savefig("../Images/Latitude_vs_Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_latitude, city_cloudiness,edgecolor="black",alpha=0.75)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness ({date.today().strftime('%m/%d/%Y')})")
plt.savefig("../Images/Latitude_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_latitude, city_wind_speed,edgecolor="black",alpha=0.75)
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed ({date.today().strftime('%m/%d/%Y')})")
plt.savefig("../Images/Latitude_vs_Wind_Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Calculate the correlation coefficient and linear regression model 
northern_hem=weather_df.loc[weather_df["Lat"]>=0]
southern_hem=weather_df.loc[weather_df["Lat"]<=0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_north=northern_hem["Lat"]
y_north_temp=northern_hem["Max Temp"]
correlation=linregress(x_north,y_north_temp)[2]

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = linregress(x_north,y_north_temp)
vc_fit = vc_slope * x_north + vc_int
line_eq = "y = " + str(round(vc_slope,2)) + "x + " + str(round(vc_int,2))
plt.scatter(x_north,y_north_temp)
plt.plot(x_north,vc_fit,"-",color="r",linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.plot(x_north,vc_fit,"r-")
plt.annotate(line_eq,(10,10),fontsize=12,color="red")
print(f"The r-value is: {correlation}")
plt.show()
# Out:
# The r-value is: -0.8566930810455577

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_south=southern_hem["Lat"]
y_south_temp=southern_hem["Max Temp"]
correlation=linregress(x_south,y_south_temp)[2]

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = linregress(x_south,y_south_temp)
vc_fit = vc_slope * x_south + vc_int
line_eq = "y = " + str(round(vc_slope,2)) + "x + " + str(round(vc_int,2))
plt.scatter(x_south, y_south_temp)
plt.plot(x_south,vc_fit,"-",color="r",linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.plot(x_south,vc_fit,"r-")
plt.annotate(line_eq,(-25,50),fontsize=12,color="red")
print(f"The r-value is: {correlation}")
plt.show()
# Out:
# The r-value is: 0.6972671050783296

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_north=northern_hem["Lat"]
y_north_humidity=northern_hem["Humidity"]
correlation=linregress(x_north,y_north_humidity)[2]

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = linregress(x_north,y_north_humidity)
vc_fit = vc_slope * x_north + vc_int
line_eq = "y = " + str(round(vc_slope,2)) + "x + " + str(round(vc_int,2))
plt.scatter(x_north,y_north_humidity)
plt.plot(x_north,vc_fit,"-",color="r",linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.plot(x_north,vc_fit,"r-")
plt.annotate(line_eq,(50,10),fontsize=12,color="red")
print(f"The r-value is: {correlation}")
plt.show()
# Out:
# The r-value is: 0.14718270094288763

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_south=southern_hem["Lat"]
y_south_humidity=southern_hem["Humidity"]
correlation=linregress(x_south,y_south_humidity)[2]

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = linregress(x_south,y_south_humidity)
vc_fit = vc_slope * x_south + vc_int
line_eq = "y = " + str(round(vc_slope,2)) + "x + " + str(round(vc_int,2))
plt.scatter(x_south, y_south_humidity)
plt.plot(x_south,vc_fit,"-",color="r",linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.plot(x_south,vc_fit,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
print(f"The r-value is: {correlation}")
plt.show()
# Out:
# The r-value is: 0.15054772400031508

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_north=northern_hem["Lat"]
y_north_cloudiness=northern_hem["Cloudiness"]
correlation=linregress(x_north,y_north_cloudiness)[2]

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = linregress(x_north,y_north_cloudiness)
vc_fit = vc_slope * x_north + vc_int
line_eq = "y = " + str(round(vc_slope,2)) + "x + " + str(round(vc_int,2))
plt.scatter(x_north,y_north_cloudiness)
plt.plot(x_north,vc_fit,"-",color="r",linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.plot(x_north,vc_fit,"r-")
plt.annotate(line_eq,(40,50),fontsize=15,color="red")
print(f"The r-value is: {correlation}")
plt.show()
# Out:
# The r-value is: 0.06342496555811698

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_south=southern_hem["Lat"]
y_south_cloudiness=southern_hem["Cloudiness"]
correlation=linregress(x_south,y_south_cloudiness)[2]

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = linregress(x_south,y_south_cloudiness)
vc_fit = vc_slope * x_south + vc_int
line_eq = "y = " + str(round(vc_slope,2)) + "x + " + str(round(vc_int,2))
plt.scatter(x_south, y_south_cloudiness)
plt.plot(x_south,vc_fit,"-",color="r",linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.plot(x_south,vc_fit,"r-")
plt.annotate(line_eq,(-50,30),fontsize=15,color="red")
print(f"The r-value is: {correlation}")
plt.show()
# Out:
# The r-value is: 0.03141018581120828

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_north=northern_hem["Lat"]
y_north_wind=northern_hem["Wind"]
correlation=linregress(x_north,y_north_wind)[2]

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = linregress(x_north,y_north_wind)
vc_fit = vc_slope * x_north + vc_int
line_eq = "y = " + str(round(vc_slope,2)) + "x + " + str(round(vc_int,2))
plt.scatter(x_north,y_north_wind)
plt.plot(x_north,vc_fit,"-",color="r",linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.plot(x_north,vc_fit,"r-")
plt.annotate(line_eq,(10,30),fontsize=15,color="red")
print(f"The r-value is: {correlation}")
plt.show()
# Out:
# The r-value is: 0.18175241975336903

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_south=southern_hem["Lat"]
y_south_wind=southern_hem["Wind"]
correlation=linregress(x_south,y_south_wind)[2]

# %%
vc_slope, vc_int, vc_r, vc_p, vc_std_err = linregress(x_south,y_south_wind)
vc_fit = vc_slope * x_south + vc_int
line_eq = "y = " + str(round(vc_slope,2)) + "x + " + str(round(vc_int,2))
plt.scatter(x_south, y_south_wind)
plt.plot(x_south,vc_fit,"-",color="r",linewidth=1)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.plot(x_south,vc_fit,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
print(f"The r-value is: {correlation}")
plt.show()
# Out:
# The r-value is: -0.1786595947735044
